# %%
#Task A
import pandas as pd
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.util import ngrams
from collections import Counter

nltk.download('punkt')
nltk.download('wordnet')
nltk.download('stopwords')

df = pd.read_csv('train (5).csv')

disaster_tweets = df[df['target'] == 1]
normal_tweets = df[df['target'] == 0]

print("normal" ,normal_tweets)
print("disaster" , disaster_tweets)
# Out:
# normal          id  keyword location  \
# 15       23      NaN      NaN
# 16       24      NaN      NaN
# 17       25      NaN      NaN
# 18       26      NaN      NaN
# 19       28      NaN      NaN
# ...     ...      ...      ...
# 7581  10833  wrecked  Lincoln
# 7582  10834  wrecked      NaN
# 7584  10837      NaN      NaN
# 7587  10841      NaN      NaN
# 7593  10848      NaN      NaN
#
#                                                    text  target
# 15                                       What's up man?       0
# 16                                        I love fruits       0
# 17                                     Summer is lovely       0
# 18                                    My car is so fast       0
# 19                         What a goooooooaaaaaal!!!!!!       0
# ...                                                 ...     ...
# 7581  @engineshed Great atmosphere at the British Li...       0
# 7582  Cramer: Iger's 3 words that wrecked Disney's s...       0
# 7584  These boxes are ready to explode! Exploding Ki...       0
# 7587                                 Sirens everywhere!       0
# 7593  I just heard a really loud bang and everyone i...       0
#
# [4342 rows x 5 columns]
# disaster          id keyword location  \
# 0         1     NaN      NaN
# 1         4     NaN      NaN
# 2         5     NaN      NaN
# 3         6     NaN      NaN
# 4         7     NaN      NaN
# ...     ...     ...      ...
# 7608  10869     NaN      NaN
# 7609  10870     NaN      NaN
# 7610  10871     NaN      NaN
# 7611  10872     NaN      NaN
# 7612  10873     NaN      NaN
#
#                                                    text  target
# 0     Our Deeds are the Reason of this #earthquake M...       1
# 1                Forest fire near La Ronge Sask. Canada       1
# 2     All residents asked to 'shelter in place' are ...       1
# 3     13,000 people receive #wildfires evacuation or...       1
# 4     Just got sent this photo from Ruby #Alaska as ...       1
# ...                                                 ...     ...
# 7608  Two giant cranes holding a bridge collapse int...       1
# 7609  @aria_ahrary @TheTawniest The out of control w...       1
# 7610  M1.94 [01:04 UTC]?5km S of Volcano Hawaii. htt...       1
# 7611  Police investigating after an e-bike collided ...       1
# 7612  The Latest: More Homes Razed by Northern Calif...       1
#
# [3271 rows x 5 columns]
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def preprocess_tweets(tweets):
    lemmatizer = nltk.WordNetLemmatizer()
    tokens = []
    for tweet in tweets:

        words = word_tokenize(tweet.lower())
        words = [word for word in words if word.isalpha()]
        words = [word for word in words if word not in stopwords.words('english')]

        words = [lemmatizer.lemmatize(word) for word in words]
        tokens.extend(words)
    return tokens

disaster_tokens = preprocess_tweets(disaster_tweets['text'])
print(disaster_tokens)

normal_tokens = preprocess_tweets(normal_tweets['text'])
print(normal_tokens)
# Out:
# ['deed', 'reason', 'earthquake', 'may', 'allah', 'forgive', 'u', 'forest', 'fire', 'near', 'la', 'ronge', 'sask', 'canada', 'resident', 'asked', 'place', 'notified', 'officer', 'evacuation', 'shelter', 'place', 'order', 'expected', 'people', 'receive', 'wildfire', 'evacuation', 'order', 'california', 'got', 'sent', 'photo', 'ruby', 'alaska', 'smoke', 'wildfire', 'pours', 'school', 'rockyfire', 'update', 'california', 'hwy', 'closed', 'direction', 'due', 'lake', 'county', 'fire', 'cafire', 'wildfire', 'flood', 'disaster', 'heavy', 'rain', 'cause', 'flash', 'flooding', 'street', 'manitou', 'colorado', 'spring', 'area', 'top', 'hill', 'see', 'fire', 'wood', 'emergency', 'evacuation', 'happening', 'building', 'across', 'street', 'afraid', 'tornado', 'coming', 'area', 'three', 'people', 'died', 'heat', 'wave', 'far', 'haha', 'south', 'tampa', 'getting', 'flooded', 'wait', 'second', 'live', 'south', 'tampa', 'gon', 'na', 'gon', 'na', 'fvck', 'flooding', 'raining', 'flooding', 'florida', 'tampabay', 'tampa', 'day', 'lost', 'count', 'flood', 'bago', 'myanmar', 'arrived', 'bago', 'damage', 'school', 'bus', 'multi', 'car', 'crash', 'breaking', 'bbcmtd', 'wholesale', 'market', 'ablaze', 'http', 'africanbaze', 'breaking', 'news', 'nigeria', 'flag', 'set', 'ablaze', 'aba', 'http', 'inec', 'office', 'abia', 'set', 'ablaze', 'http', 'barbados', 'bridgetown', 'jamaica', 'two', 'car', 'set', 'ablaze', 'santa', 'cruz', 'head', 'st', 'elizabeth', 'police', 'superintende', 'http', 'west', 'burned', 'thousand', 'wildfire', 'ablaze', 'california', 'alone', 'http', 'deputy', 'man', 'shot', 'brighton', 'home', 'set', 'ablaze', 'http', 'man', 'wife', 'get', 'six', 'year', 'jail', 'setting', 'ablaze', 'niece', 'http', 'police', 'arsonist', 'deliberately', 'set', 'black', 'church', 'north', 'carolinaåêablaze', 'http', 'kurd', 'trampling', 'turkmen', 'flag', 'later', 'set', 'ablaze', 'others', 'vandalized', 'office', 'turkmen', 'front', 'diyala', 'http', 'truck', 'ablaze', 'voortrekker', 'outside', 'tambo', 'intl', 'cargo', 'section', 'http', 'west', 'burned', 'thousand', 'wildfire', 'ablaze', 'california', 'alone', 'http', 'climate', 'energy', 'http', 'steve', 'fire', 'something', 'else', 'california', 'tinderbox', 'clown', 'setting', 'ablaze', 'nxwestmidlands', 'huge', 'fire', 'wholesale', 'market', 'ablaze', 'http', 'accident', 'w', 'nashvilletraffic', 'traffic', 'moving', 'slower', 'usual', 'http', 'accident', 'center', 'lane', 'blocked', 'santaclara', 'nb', 'great', 'america', 'pkwy', 'bayarea', 'traffic', 'http', 'reported', 'motor', 'vehicle', 'accident', 'curry', 'herman', 'rd', 'near', 'stephenson', 'involving', 'overturned', 'vehicle', 'please', 'use', 'http', 'bigrigradio', 'live', 'accident', 'awareness', 'mile', 'marker', 'south', 'mooresville', 'iredell', 'vehicle', 'accident', 'ramp', 'closed', 'pm', 'traffic', 'accident', 'n', 'cabrillo', 'av', 'mir', 'mile', 'marker', 'south', 'mooresville', 'iredell', 'vehicle', 'accident', 'congestion', 'pm', 'pastor', 'scene', 'accident', 'owner', 'range', 'rover', 'horrible', 'car', 'accident', 'past', 'sunday', 'finally', 'able', 'get', 'around', 'thank', 'god', 'truckcrash', 'overturn', 'fortworth', 'interstate', 'http', 'click', 'crash', 'gt', 'http', 'accident', 'ashville', 'u', 'sb', 'sr', 'traffic', 'http', 'carolina', 'accident', 'motorcyclist', 'dy', 'crash', 'car', 'crossed', 'median', 'motorcycle', 'rider', 'traveling', 'http', 'fyi', 'cad', 'fyi', 'accident', 'property', 'damage', 'nh', 'piner', 'dr', 'rt', 'naayf', 'first', 'accident', 'year', 'turning', 'onto', 'chandanee', 'magu', 'near', 'mma', 'taxi', 'rammed', 'halfway', 'turned', 'everyone', 'accident', 'left', 'lane', 'blocked', 'manchester', 'rt', 'nb', 'eddy', 'rd', 'stop', 'go', 'traffic', 'back', 'delay', 'min', 'traffic', 'accident', 'property', 'damage', 'piner', 'dr', 'fyi', 'cad', 'fyi', 'accident', 'property', 'damage', 'wpd', 'st', 'pm', 'traffic', 'accident', 'injury', 'willis', 'foreman', 'rd', 'http', 'aashiqui', 'actr ...
# ['man', 'love', 'fruit', 'summer', 'lovely', 'car', 'fast', 'goooooooaaaaaal', 'ridiculous', 'london', 'cool', 'love', 'skiing', 'wonderful', 'day', 'looooool', 'way', 'ca', 'eat', 'shit', 'nyc', 'last', 'week', 'love', 'girlfriend', 'cooool', 'like', 'pasta', 'end', 'always', 'try', 'bring', 'heavy', 'metal', 'rt', 'http', 'cry', 'set', 'ablaze', 'plus', 'side', 'look', 'sky', 'last', 'night', 'ablaze', 'http', 'phdsquares', 'mufc', 'built', 'much', 'hype', 'around', 'new', 'acquisition', 'doubt', 'set', 'epl', 'ablaze', 'season', 'ablaze', 'lord', 'check', 'http', 'http', 'http', 'http', 'nsfw', 'outside', 'ablaze', 'alive', 'dead', 'inside', 'awesome', 'time', 'visiting', 'cfc', 'head', 'office', 'ancop', 'site', 'ablaze', 'thanks', 'tita', 'vida', 'taking', 'care', 'u', 'soooo', 'pumped', 'ablaze', 'southridgelife', 'wanted', 'set', 'chicago', 'ablaze', 'preaching', 'hotel', 'http', 'gained', 'follower', 'last', 'week', 'know', 'stats', 'grow', 'http', 'building', 'perfect', 'tracklist', 'life', 'leave', 'street', 'ablaze', 'check', 'http', 'http', 'http', 'http', 'nsfw', 'first', 'night', 'retainer', 'quite', 'weird', 'better', 'get', 'used', 'wear', 'every', 'single', 'night', 'next', 'year', 'least', 'santa', 'cruz', 'head', 'st', 'elizabeth', 'police', 'superintendent', 'lanford', 'salmon', 'r', 'http', 'http', 'noches', 'happy', 'see', 'teammate', 'training', 'hard', 'goodnight', 'http', 'set', 'heart', 'ablaze', 'every', 'city', 'gift', 'every', 'skyline', 'like', 'kiss', 'upon', 'lip', 'http', 'sky', 'ablaze', 'tonight', 'los', 'angeles', 'expecting', 'ig', 'fb', 'filled', 'sunset', 'shot', 'know', 'peep', 'revel', 'wmv', 'video', 'mean', 'mac', 'farewell', 'ablaze', 'wmv', 'en', 'route', 'dvd', 'gtxrwm', 'progressive', 'greeting', 'month', 'student', 'would', 'set', 'pen', 'ablaze', 'torch', 'publication', 'http', 'rene', 'ablaze', 'amp', 'jacinta', 'secret', 'fallen', 'sky', 'edit', 'mar', 'http', 'nowplaying', 'rene', 'ablaze', 'amp', 'ian', 'buff', 'magnitude', 'http', 'edm', 'ablaze', 'time', 'talk', 'go', 'know', 'make', 'due', 'work', 'ca', 'kid', 'cuz', 'got', 'bicycle', 'accident', 'amp', 'split', 'testicle', 'impossible', 'kid', 'michael', 'father', 'http', 'personalinjury', 'accident', 'summer', 'read', 'advice', 'amp', 'see', 'solicitor', 'help', 'otleyhour', 'stlouis', 'caraccidentlawyer', 'speeding', 'among', 'top', 'cause', 'teen', 'accident', 'http', 'http', 'car', 'accident', 'rt', 'sleepjunkies', 'sleeping', 'pill', 'double', 'risk', 'car', 'accident', 'http', 'accident', 'knew', 'gon', 'happen', 'http', 'mom', 'get', 'home', 'fast', 'wished', 'mom', 'accident', 'truck', 'spilt', 'mayonnaise', 'wait', 'see', 'pissed', 'donnie', 'tell', 'another', 'accident', 'accident', 'http', 'accident', 'changed', 'life', 'help', 'determine', 'option', 'financially', 'support', 'life', 'care', 'plan', 'treatment', 'flowri', 'marinading', 'accident', 'still', 'heard', 'church', 'leader', 'kenya', 'coming', 'forward', 'comment', 'accident', 'issue', 'disciplinary', 'measure', 'arrestpastornganga', 'scuf', 'p', 'live', 'game', 'cya', 'man', 'drive', 'effort', 'get', 'painful', 'man', 'win', 'roger', 'bannister', 'ir', 'icemoon', 'aftershock', 'http', 'djicemoon', 'dubstep', 'trapmusic', 'dnb', 'edm', 'dance', 'http', 'victory', 'bargain', 'basement', 'price', 'dwight', 'david', 'eisenhower', 'ir', 'icemoon', 'aftershock', 'http', 'djicemoon', 'dubstep', 'trapmusic', 'dnb', 'edm', 'dance', 'http', 'remembers', 'came', 'second', 'charles', 'schulz', 'im', 'speaking', 'someone', 'using', 'scuf', 'people', 'end', 'getting', 'p', 'also', 'harder', 'conflict', 'glorious', 'triumph', 'thomas', 'paine', 'growingupspoiled', 'going', 'clay', 'pigeon', 'shooting', 'cry', 'guess', 'one', 'actually', 'want', 'free', 'aftershock', 'tc', 'aftershock', 'terrifying', 'best', 'roller', 'coaster', 'ever', 'disclaimer', 'aftershock', 'http', 'ir', 'icemoon', 'aftershock', 'http', 'djicemoon', 'dubstep', 'trapmusic', 'dnb', 'edm', 'dan ...

# %%
disaster_tokens = preprocess_tweets(disaster_tweets['text'])
normal_tokens = preprocess_tweets(normal_tweets['text'])

disaster_word_count = Counter(disaster_tokens)
print("disaster", disaster_word_count)

normal_word_count = Counter(normal_tokens)
print("normal", normal_word_count)
# Out:
# disaster Counter({'http': 2513, 'fire': 261, 'news': 140, 'amp': 135, 'via': 121, 'disaster': 119, 'california': 111, 'police': 107, 'people': 105, 'family': 105, 'suicide': 104, 'home': 102, 'train': 100, 'building': 94, 'killed': 93, 'like': 93, 'storm': 92, 'crash': 90, 'bomb': 90, 'hiroshima': 87, 'year': 83, 'wildfire': 79, 'flood': 79, 'attack': 76, 'emergency': 74, 'bombing': 74, 'accident': 73, 'two': 72, 'video': 72, 'car': 71, 'u': 70, 'get': 70, 'nuclear': 70, 'one': 69, 'say': 67, 'death': 64, 'northern': 64, 'burning': 64, 'dead': 63, 'legionnaire': 61, 'bomber': 61, 'war': 60, 'pm': 59, 'life': 59, 'time': 57, 'still': 57, 'atomic': 56, 'new': 55, 'obama': 55, 'japan': 55, 'collapse': 55, 'today': 54, 'kill': 53, 'fatal': 53, 'warning': 51, 'forest': 50, 'debris': 50, 'watch': 50, 'may': 49, 'report': 49, 'man': 48, 'first': 48, 'look': 48, 'latest': 48, 'city': 48, 'water': 48, 'malaysia': 48, 'near': 47, 'hostage': 47, 'severe': 47, 'thunderstorm': 47, 'mass': 47, 'earthquake': 46, 'rt': 46, 'migrant': 46, 'confirmed': 45, 'found': 44, 'world': 44, 'oil': 44, 'area': 43, 'day': 43, 'injured': 43, 'evacuation': 42, 'army': 42, 'spill': 42, 'service': 41, 'outbreak': 41, 'casualty': 41, 'derailment': 41, 'state': 40, 'could': 40, 'weather': 40, 'wreckage': 40, 'saudi': 39, 'terrorist': 39, 'house': 38, 'weapon': 38, 'old': 38, 'flooding': 37, 'bus': 37, 'official': 37, 'would': 37, 'missing': 37, 'bridge': 37, 'rain': 36, 'damage': 36, 'back': 36, 'island': 36, 'suspect': 36, 'wind': 36, 'investigator': 36, 'mosque': 35, 'murder': 35, 'rescuer': 35, 'plan': 35, 'update': 34, 'truck': 34, 'go': 34, 'wild': 34, 'boy': 34, 'charged': 34, 'body': 34, 'refugee': 34, 'wounded': 34, 'fatality': 34, 'another': 33, 'anniversary': 33, 'hundred': 33, 'got': 32, 'school': 32, 'shot': 32, 'injury': 32, 'air': 32, 'hit': 32, 'many': 32, 'drought': 32, 'affected': 32, 'officer': 31, 'county': 31, 'cause': 31, 'heat': 31, 'airplane': 31, 'reunion': 31, 'plane': 31, 'survivor': 31, 'take': 31, 'pkk': 31, 'typhoon': 31, 'detonated': 31, 'wave': 30, 'live': 30, 'ca': 30, 'airport': 30, 'minute': 30, 'photo': 29, 'know': 29, 'since': 29, 'woman': 29, 'flame': 29, 'calgary': 29, 'evacuated': 29, 'massacre': 29, 'razed': 29, 'see': 28, 'road': 28, 'explosion': 28, 'israeli': 28, 'released': 28, 'going': 28, 'turkey': 28, 'hurricane': 28, 'evacuate': 28, 'boat': 28, 'terrorism': 28, 'sandstorm': 28, 'tornado': 27, 'way': 27, 'last': 27, 'sign': 27, 'issue': 27, 'violent': 27, 'abc': 27, 'natural': 27, 'failure': 27, 'caused': 27, 'sue': 27, 'please': 26, 'helicopter': 26, 'least': 26, 'india': 26, 'attacked': 26, 'said': 26, 'iran': 26, 'group': 26, 'crew': 26, 'declares': 26, 'devastation': 26, 'sinkhole': 26, 'set': 25, 'case': 25, 'child': 25, 'august': 25, 'hail': 25, 'story': 25, 'displaced': 25, 'volcano': 25, 'collided': 25, 'collision': 25, 'soudelor': 25, 'derailed': 25, 'saipan': 25, 'dust': 25, 'structural': 25, 'swallowed': 25, 'due': 24, 'street': 24, 'aircraft': 24, 'victim': 24, 'call': 24, 'ambulance': 24, 'help': 24, 'post': 24, 'make': 24, 'horror': 24, 'land': 24, 'mp': 24, 'catastrophic': 24, 'memory': 24, 'projected': 24, 'lightning': 24, 'bestnaijamade': 24, 'south': 23, 'breaking': 23, 'right': 23, 'shooting': 23, 'reuters': 23, 'need': 23, 'fear': 23, 'possible': 23, 'tragedy': 23, 'bigger': 23, 'village': 23, 'searching': 23, 'rioting': 23, 'site': 23, 'manslaughter': 23, 'three': 22, 'west': 22, 'north': 22, 'traffic': 22, 'gt': 22, 'even': 22, 'youtube': 22, 'crashed': 22, 'feared': 22, 'muslim': 22, 'landslide': 22, 'isi': 22, 'famine': 22, 'trench': 22, 'refugio': 22, 'costlier': 22, 'order': 21, 'died': 21, 'past': 21, 'stop': 21, 'expert': 21, 'come': 21, 'pakistan': 21, 'saw': 21, 'amid': 21, 'power': 21, 'lab': 21, 'security': 21, 'american': 21, 'hot': 21, 'rescue': 21, 'pic': 21, 'hazardous': 21, 'la': 20, 'black': 20, 'good': 20, 'government': 20, 'national': 20, 'arson': 20, 'militant': 20, 'christi ...
# normal Counter({'http': 2203, 'like': 255, 'amp': 209, 'get': 184, 'new': 168, 'u': 135, 'one': 135, 'body': 114, 'would': 105, 'time': 103, 'video': 102, 'via': 97, 'love': 94, 'day': 93, 'people': 93, 'got': 92, 'know': 90, 'go': 90, 'fire': 88, 'back': 85, 'see': 84, 'emergency': 82, 'full': 81, 'bag': 81, 'want': 80, 'let': 80, 'youtube': 76, 'make': 75, 'going': 75, 'ca': 74, 'look': 72, 'world': 72, 'still': 71, 'gt': 70, 'need': 70, 'think': 69, 'life': 67, 'good': 67, 'year': 64, 'say': 63, 'man': 62, 'na': 62, 'lol': 62, 'woman': 62, 'rt': 61, 'way': 60, 'take': 59, 'first': 57, 'work': 57, 'news': 57, 'last': 56, 'burning': 56, 'really': 55, 'injury': 55, 'feel': 55, 'best': 54, 'thing': 54, 'reddit': 53, 'much': 51, 'many': 51, 'even': 51, 'come': 51, 'help': 50, 'right': 50, 'god': 49, 'could': 48, 'black': 48, 'weapon': 48, 'today': 47, 'great': 47, 'building': 46, 'wreck': 46, 'hot': 46, 'content': 46, 'please': 45, 'death': 45, 'fear': 45, 'read': 44, 'cross': 44, 'im': 43, 'never': 43, 'every': 42, 'as': 42, 'night': 41, 'ever': 41, 'service': 41, 'siren': 41, 'top': 40, 'plan': 40, 'game': 40, 'job': 40, 'everyone': 40, 'fucking': 40, 'girl': 40, 'car': 39, 'check': 39, 'war': 39, 'ruin': 39, 'another': 38, 'school': 38, 'may': 38, 'change': 38, 'show': 38, 'disaster': 38, 'fatality': 38, 'shit': 37, 'getting': 37, 'guy': 37, 'without': 37, 'liked': 37, 'photo': 37, 'smoke': 37, 'panic': 37, 'explode': 37, 'always': 36, 'head': 36, 'gon': 36, 'home': 36, 'coming': 36, 'screaming': 36, 'bloody': 36, 'face': 36, 'stop': 36, 'watch': 36, 'wrecked': 36, 'bad': 35, 'fall': 35, 'someone': 34, 'lot': 34, 'movie': 34, 'fan': 34, 'hope': 34, 'military': 34, 'sound': 34, 'keep': 34, 'harm': 34, 'crush': 34, 'sinking': 34, 'dead': 33, 'next': 33, 'police': 33, 'also': 33, 'run': 33, 'made': 33, 'flood': 33, 'storm': 33, 'loud': 33, 'week': 32, 'better': 32, 'free': 32, 'phone': 32, 'ebay': 32, 'attack': 32, 'fuck': 32, 'crash': 32, 'eye': 32, 'curfew': 32, 'screamed': 32, 'traumatised': 32, 'twister': 32, 'blood': 31, 'said': 31, 'well': 31, 'little': 31, 'song': 31, 'put': 31, 'word': 31, 'blew': 31, 'end': 30, 'live': 30, 'book': 30, 'destroy': 30, 'armageddon': 30, 'start': 30, 'long': 30, 'army': 30, 'friend': 30, 'wan': 30, 'bleeding': 30, 'shoulder': 30, 'nuclear': 30, 'deluge': 30, 'stock': 30, 'panicking': 30, 'light': 29, 'burned': 29, 'business': 29, 'flame': 29, 'battle': 29, 'blazing': 29, 'bomb': 29, 'drown': 29, 'survive': 29, 'trouble': 29, 'inundated': 29, 'lava': 29, 'scream': 29, 'summer': 28, 'heart': 28, 'kid': 28, 'meltdown': 28, 'soon': 28, 'real': 28, 'thought': 28, 'destroyed': 28, 'lady': 28, 'big': 28, 'blown': 28, 'baby': 28, 'wave': 28, 'catastrophe': 28, 'collide': 28, 'desolation': 28, 'flattened': 28, 'quarantine': 28, 'sunk': 28, 'cause': 27, 'thank': 27, 'play': 27, 'two': 27, 'family': 27, 'hit': 27, 'market': 27, 'bagging': 27, 'destruction': 27, 'cliff': 27, 'trapped': 27, 'crushed': 27, 'danger': 27, 'electrocute': 27, 'bang': 27, 'obliterated': 27, 'set': 26, 'away': 26, 'apocalypse': 26, 'twitter': 26, 'music': 26, 'story': 26, 'oh': 26, 'hazard': 26, 'demolish': 26, 'obliterate': 26, 'riot': 26, 'hour': 25, 'fun': 25, 'high': 25, 'sure': 25, 'house': 25, 'whole': 25, 'drowning': 25, 'survived': 25, 'hostage': 25, 'obliteration': 25, 'thunder': 25, 'wound': 25, 'tonight': 24, 'nowplaying': 24, 'accident': 24, 'heard': 24, 'call': 24, 'nigga': 24, 'zone': 24, 'red': 24, 'collapse': 24, 'white': 24, 'mass': 24, 'blight': 24, 'policy': 24, 'ur': 24, 'handbag': 24, 'damage': 24, 'upheaval': 24, 'around': 23, 'something': 23, 'annihilated': 23, 'reason': 23, 'since': 23, 'tomorrow': 23, 'stay': 23, 'child': 23, 'collapsed': 23, 'exploded': 23, 'hellfire': 23, 'quarantined': 23, 'whirlwind': 23, 'windstorm': 23, 'cool': 22, 'wait': 22, 'already': 22, 'making': 22, 'ship': 22, 'bar': 22, 'beautiful': 22, 'yet': 22, 'nothing': 22, 'old': 22, 'cake': 22, 'detonation': 22, 'mudslide': 22, 'pa ...

# %%
top_20_disaster_words = disaster_word_count.most_common(20)
top_20_normal_words = normal_word_count.most_common(20)

print("Top 20 disaster words:", top_20_disaster_words)
print("Top 20 normal words:", top_20_normal_words)

def get_top_ngrams(tokens, n=2, top_n=20):
    n_grams = ngrams(tokens, n)
    n_gram_freq = Counter(n_grams)
    return n_gram_freq.most_common(top_n)


top_20_disaster_bigrams = get_top_ngrams(disaster_tokens, n=2, top_n=20)
top_20_disaster_trigrams = get_top_ngrams(disaster_tokens, n=3, top_n=20)
top_20_normal_bigrams = get_top_ngrams(normal_tokens, n=2, top_n=20)
top_20_normal_trigrams = get_top_ngrams(normal_tokens, n=3, top_n=20)


print("Top 20 disaster bigrams:", top_20_disaster_bigrams)
print("Top 20 disaster trigrams:", top_20_disaster_trigrams)
print("Top 20 normal bigrams:", top_20_normal_bigrams)
print("Top 20 normal trigrams:", top_20_normal_trigrams)

# %%
#Task B
import pandas as pd
import re
import nltk
from nltk.corpus import stopwords
from string import punctuation

nltk.download('stopwords')

df = pd.read_csv('train (5).csv')

disaster_tweets = df[df['target'] == 1]
normal_tweets = df[df['target'] == 0]

def preprocess_tweet(tweet):
    tweet = re.sub(r'@\w+', '', tweet)
    tweet = ''.join([char for char in tweet if char not in punctuation])
    tweet = tweet.lower()
    stop_words = set(stopwords.words('english'))
    tweet = ' '.join([word for word in tweet.split() if word not in stop_words])
    return tweet


disaster_tweets['text'] = disaster_tweets['text'].apply(preprocess_tweet)
normal_tweets['text'] = normal_tweets['text'].apply(preprocess_tweet)

print("Disaster tweets:", disaster_tweets['text'])
print("Normal tweets:", normal_tweets['text'])

# %%
# Task C
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, f1_score, recall_score

train_df = pd.read_csv('train.csv')


X_train, X_val, y_train, y_val = train_test_split(train_df['review'], train_df['sentiment'], test_size=0.2, random_state=42)

def train_and_evaluate(max_features):
    # Vectorizing text data
    vectorizer = CountVectorizer(max_features=max_features)
    X_train_vect = vectorizer.fit_transform(X_train)
    X_val_vect = vectorizer.transform(X_val)


    lr_model = LogisticRegression(max_iter=1000)
    lr_model.fit(X_train_vect, y_train)

    y_pred = lr_model.predict(X_val_vect)

    accuracy = accuracy_score(y_val, y_pred)
    f1 = f1_score(y_val, y_pred, pos_label='positive')
    recall = recall_score(y_val, y_pred, pos_label='positive')

    return accuracy, f1, recall

results_100 = train_and_evaluate(100)
results_1000 = train_and_evaluate(1000)

print("results_100" ,results_100)
print("results_1000" , results_1000)
# Out:
# results_100 (0.733625, 0.7349172782684413, 0.7539561000510464)
# results_1000 (0.865, 0.8639798488664988, 0.8754466564573762)
